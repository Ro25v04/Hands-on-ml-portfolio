# %% [markdown]
# <a href="https://colab.research.google.com/github/Ro25v04/Hands-on-ml-portfolio/blob/main/01_regression/end_to_end_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **End-to-End Machine Learning Project**

# %% [markdown]
# This Project uses census data to build a model of housing prices in the state of California.

# %%
print("Welcome to the Real Estate Machine Learning Project!")
# Out:
# Welcome to the Real Estate Machine Learning Project!

# %% [markdown]
# This project requires Python 3.10 version or above:

# %%
import sys

assert sys.version_info >= (3, 10)

# %% [markdown]
# This project also requires a Scikit-Learn version of 1.6.1 or above:

# %%
from packaging.version import Version
import sklearn

assert Version(sklearn.__version__) >= Version("1.6.1")

# %% [markdown]
# # Getting the data

# %% [markdown]
# This project's task is to predict the median house values in Californian districts, given a number of features from these districts

# %% [markdown]
# ## Downloading the Data

# %%
from pathlib import Path
import pandas as pd
import tarfile
import urllib.request
